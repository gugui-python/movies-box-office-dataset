# %% [markdown]
# <a href="https://colab.research.google.com/github/gugui-python/movies-box-office-dataset/blob/main/datasets%2Bperello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad práctica 2.8**

# %%
import pandas as pd

# URLs corregidas (asegúrate de que existan en tu repo)
url_movies = "https://raw.githubusercontent.com/gugui-python/movies-box-office-dataset/main/enhanced_box_office_data(2000-2024)u.csv"
url_songs = "https://raw.githubusercontent.com/gugui-python/movies-box-office-dataset/main/songs_2000_2020_50k.csv"
url_exports = "https://raw.githubusercontent.com/gugui-python/movies-box-office-dataset/main/34_years_world_export_import_dataset.csv"

# Cargar los datasets
df_movies = pd.read_csv(url_movies)
df_songs = pd.read_csv(url_songs)
df_exports = pd.read_csv(url_exports)

# Mostrar las primeras filas de cada dataset
print("Movies Dataset:")
display(df_movies.head())

print("Songs Dataset:")
display(df_songs.head())

print("Exports Dataset:")
display(df_exports.head())
# Out:
# Movies Dataset:
#    Rank           Release Group   $Worldwide    $Domestic  Domestic %  \
# 0     1  Mission: Impossible II  546388108.0  215409889.0        39.4
# 1     2               Gladiator  460583960.0  187705427.0        40.8
# 2     3               Cast Away  429632142.0  233632142.0        54.4
# 3     4         What Women Want  374111707.0  182811707.0        48.9
# 4     5                Dinosaur  349822765.0  137748063.0        39.4
#
#       $Foreign  Foreign %  Year                        Genres    Rating  \
# 0  330978219.0       60.6  2000   Adventure, Action, Thriller  6.126/10
# 1  272878533.0       59.2  2000      Action, Drama, Adventure  8.217/10
# 2  196000000.0       45.6  2000              Adventure, Drama  7.663/10
# 3  191300000.0       51.1  2000               Comedy, Romance   6.45/10
# 4  212074702.0       60.6  2000  Animation, Family, Adventure  6.544/10
#
#    Vote_Count Original_Language                      Production_Countries
# ...

# %%
print("Columnas en Movies Dataset:", df_movies.columns)
print("Columnas en Songs Dataset:", df_songs.columns)
print("Columnas en Exports Dataset:", df_exports.columns)
# Out:
# Columnas en Movies Dataset: Index(['Rank', 'Release Group', '$Worldwide', '$Domestic', 'Domestic %',
#        '$Foreign', 'Foreign %', 'Year', 'Genres', 'Rating', 'Vote_Count',
#        'Original_Language', 'Production_Countries'],
#       dtype='object')
# Columnas en Songs Dataset: Index(['Title', 'Artist', 'Album', 'Genre', 'Release Date', 'Duration',
#        'Popularity'],
#       dtype='object')
# Columnas en Exports Dataset: Index(['Partner Name', 'Year', 'Export (US$ Thousand)',
#        'Import (US$ Thousand)', 'Export Product Share (%)',
#        'Import Product Share (%)', 'Revealed comparative advantage',
#        'World Growth (%)', 'Country Growth (%)', 'AHS Simple Average (%)',
#        'AHS Weighted Average (%)', 'AHS Total Tariff Lines',
#        'AHS Dutiable Tariff Lines Share (%)',
#        'AHS Duty Free Tariff Lines Share (%)',
#        'AHS Specific Tariff Lines Share (%)', 'AHS AVE Tariff Lines Share (%)',
#        'AHS MaxRate (%)', 'AHS MinRate (%)',
# ...

# %% [markdown]
# **COLUMNAS EN MOVIES**
# title: nombre de la película
# release_year: año de estreno
# genre: género de la película
# budget: presupuesto en dólares
# worldwide_gross: recaudación mundial
#
# **COLUMNAS EN SONGS**
# Title: nombre de la canción
# Artist: artista / banda / cantante
# Album: album / disco
# Genre: género musical
# Release Date: fecha de publicación
#
#
# **COLUMNAS EN EXPORTACIONES**
# Partner Name: nombre del país
# Year: año
# Export US$ Thousand: exportaciones en miles de dólares
# Import US$ Thousand: importaciones en miles de dólares

# %% [markdown]
# # **Actividad práctica 5.6**

# %%
import pandas as pd

# URL del archivo RAW desde tu GitHub
url_movies = "https://raw.githubusercontent.com/gugui-python/movies-box-office-dataset/main/enhanced_box_office_data(2000-2024)u.csv"

# Cargar el dataset de películas
df_movies = pd.read_csv(url_movies)

# Verificar las primeras filas
df_movies.head()
# Out:
#    Rank           Release Group   $Worldwide    $Domestic  Domestic %  \
# 0     1  Mission: Impossible II  546388108.0  215409889.0        39.4
# 1     2               Gladiator  460583960.0  187705427.0        40.8
# 2     3               Cast Away  429632142.0  233632142.0        54.4
# 3     4         What Women Want  374111707.0  182811707.0        48.9
# 4     5                Dinosaur  349822765.0  137748063.0        39.4
#
#       $Foreign  Foreign %  Year                        Genres    Rating  \
# 0  330978219.0       60.6  2000   Adventure, Action, Thriller  6.126/10
# 1  272878533.0       59.2  2000      Action, Drama, Adventure  8.217/10
# 2  196000000.0       45.6  2000              Adventure, Drama  7.663/10
# 3  191300000.0       51.1  2000               Comedy, Romance   6.45/10
# 4  212074702.0       60.6  2000  Animation, Family, Adventure  6.544/10
#
#    Vote_Count Original_Language                      Production_Countries
# ...

# %% [markdown]
#  ***Gráficos con Matplotlib***

# %%
import matplotlib.pyplot as plt

# Agrupamos por género y calculamos la recaudación promedio
genre_group = df_movies.groupby('Genres')['$Worldwide'].mean().sort_values(ascending=False).head(10)

# Creamos el gráfico
plt.figure(figsize=(10,6))
genre_group.plot(kind='bar', color='skyblue', grid=True)
plt.title('Top 10 géneros con mayor recaudación promedio mundial')
plt.ylabel('Recaudación promedio ($)')
plt.xlabel('Género')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Este no me gustó por como están agrupados los géneros.

# %%
# Agrupar por año y sumar la recaudación mundial
yearly_revenue = df_movies.groupby('Year')['$Worldwide'].sum()

# Crear gráfico de línea
plt.figure(figsize=(10,6))
plt.plot(yearly_revenue.index, yearly_revenue.values, color='green', marker='o')
plt.title('Recaudación mundial total por año')
plt.xlabel('Año')
plt.ylabel('Recaudación mundial ($)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa cómo evolucionó la recaudación total a lo largo de los años. Desde el 2000 al 2019 aumentó muchísimos, y luego en 2020 caída coincide con la pandemia. Después empieza a recuperarse de a poco.

# %%
# Promediar los porcentajes
domestic_avg = df_movies['Domestic %'].mean()
foreign_avg = df_movies['Foreign %'].mean()

# Crear gráfico de torta
plt.figure(figsize=(6,6))
plt.pie([domestic_avg, foreign_avg], labels=['Doméstico', 'Extranjero'], autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'])
plt.title('Promedio de distribución de recaudación')
plt.show()

# %% [markdown]
# Este gráfico muestra qué proporción de la recaudación proviene de EE.UU. y Canadá (doméstico) y del resto del mundo (extranjero). Sólo dos países son un 35%.

# %%
# Contar películas por país de producción
country_counts = df_movies['Production_Countries'].value_counts().head(10)

# Crear gráfico de barras
plt.figure(figsize=(10,6))
country_counts.plot(kind='bar', color='orange', grid=True)
plt.title('Top 10 países productores de películas')
plt.xlabel('País')
plt.ylabel('Cantidad de películas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se ven descentrados los índices del eje X, pero podemos apreciar como USA siempre es el mayor productor (a veces en conjunto con otros países).

# %% [markdown]
# ***Vamos ahora con Seaborn***

# %%
import seaborn as sns

# %%
# Ver qué géneros aparecen más
top_genres = df_movies['Genres'].value_counts().head(3).index

# Filtrar solo esos géneros
df_top_genres = df_movies[df_movies['Genres'].isin(top_genres)]

# Gráfico filtrado
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_top_genres, x='Year', y='$Worldwide', hue='Genres', alpha=0.7)
plt.title('Recaudación mundial por año (Top 3 géneros)')
plt.xlabel('Año')
plt.ylabel('Recaudación mundial ($)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# En este gráfico podemos ver que cada puntito es una película, y que a partir del 2019 las películas en general recaudaron mucho menos. Además, las dos películas que más recaudaron fueron antes del 2008.

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df_movies, x='Vote_Count', y='$Worldwide', scatter_kws={'alpha':0.5})
plt.title('Relación entre cantidad de votos y recaudación')
plt.xlabel('Cantidad de votos')
plt.ylabel('Recaudación mundial ($)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# No hay una relación tan directa entre la recaudación y la cantidad de votos. Lo esperable sería que las que más recaudan tengan más votos, pero no es así.

# %%
# Ver las calificaciones más comunes
top_ratings = df_movies['Rating'].value_counts().head(5).index

# Filtrar solo esas calificaciones
df_top_ratings = df_movies[df_movies['Rating'].isin(top_ratings)]

# Boxplot filtrado
plt.figure(figsize=(12,6))
sns.boxplot(data=df_top_ratings, x='Rating', y='$Worldwide', hue='Rating', palette='pastel', dodge=False)
plt.title('Distribución de recaudación mundial por rating (Top 5 ratings)')
plt.xlabel('Rating')
plt.ylabel('Recaudación mundial ($)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Este boxplot muestra la distribución de la recaudación mundial ($Worldwide) de las películas según su calificación (Rating). Además, filtramos por las 5 calificaciones más frecuentes.
#
# **Interpretación:**
# Caja central: Representa el 50% central de los datos (del 25% al 75%). Esto nos dice la recaudación típica de las películas con esa calificación.
#
# Líneas de los bigotes: Muestran los valores mínimos y máximos, a excepción de los valores atípicos.
#
# Outliers (puntos fuera de los bigotes): Son las películas que recaudaron mucho más o mucho menos que las demás. Esto puede indicar grandes éxitos o fracasos.
#
# Entonces:
# - Una película con rating 6.3 recaudó más que otras con más rating.
# - La caja verde (rating 6.5) tuvo valores muy altos (línea bigote de arriba).
# - No hay outliers más bajos que la media.
